# %%
y <- c(1,3,5,7,9,11)
plot(y)
# Out:
# plot without title

# %%
# 평균의 선을 긋고 평균임을 명시 
y <- c(2,5,7,12,15,20)
plot(y)
title(main = "연구결과")
title(sub = '2016.11.23')

m <- mean(y)
abline(h=m)
text(3.5, m ,'평균')
text(3.5, 11 ,'평균')
# Out:
# Plot with title "연구결과"

# %%
# 작도 디바이스를 열고, 파일명을 지정
png(filename = 'result1.png')

# %%
par(mfrow = c(2,2))

# 수직선을 그리는 방법 
y <- c(2,5,7,12,15,20)
plot(y)
title(main = "연구결과")
title(sub = '2016.11.23')

m <- mean(y)
abline(v=2)

# 대각선을 그리는 방법 a = 절편 b = 기울기 y = a+bx
y <- c(2,5,7,12,15,20)
plot(y)
title(main = "연구결과")
title(sub = '2016.11.23')

m <- mean(y)
abline(a = 0,b = 1, col = 'black',lty = 6)
# Out:
# Plot with title "연구결과"

# %%
# 작도 디바이스를 닫는다. 이 시점에 파일이 저장 (위치는 작업 디렉토리)
getwd()
dev.off()
# Out:
# [1] "D:/py_fi/rtest/0_r시각화 데이터_190806"
# png
#   3

# %%
# 파일 준비 
df <- read.csv('customer.csv')
head(df)
str(df)
# Out:
#   year customer
# 1 2011  20
# 2 2012  50
# 3 2013  70
# 4 2014 120
# 5 2015 150
# 6 2016 200
# 'data.frame':	6 obs. of  2 variables:
#  $ year    : int  2011 2012 2013 2014 2015 2016
#  $ customer: int  20 50 70 120 150 200

# %%
# 특정 컬럼을 벡터형식으로 저장 
xvec <- df$year
yvec<- df$customer

xvec 
yvec 

# 벡터의 각 요소에 접근
xvec[1]
yvec[3]
# Out:
# [1] 2011 2012 2013 2014 2015 2016
# [1]  20  50  70 120 150 200
# [1] 2011
# [1] 70

# %%
# 고수준 작도함수
plot(xvec,yvec)

# 저수준 작도함수 
title(main = '판매자료')
m <- mean(yvec)
abline(h = m)
text(2013.5,m+10,'평균')
# Out:
# Plot with title "판매자료"

# %%
# 수학함수를 입력 데이터로 
par(mfrow = c(2,2))
plot(sin)
plot(cos)
plot(tan)
# Out:
# plot without title

# %%
# 100개의 난수에 대한 그래프
plot(rnorm(100))

plot(runif(n = 100, min = 0, max = 10))
# Out:
# plot without title
# plot without title

# %%
x <- c(1,2,3,4,5,6)
y <- c(2,5,7,12,15,20)

plot(x,y,xlab = 'time',ylab = "effect",type = 'b', pch = 0)
# Out:
# plot without title

# %%
x <- c(1,1,1,1,1,1,2,4,3,3,3,5,2,6,7,8,6,6,7,9,10,10,20,13,13,13,13,13)
hist(x)
hist(x,breaks = 8)
# Out:
# Plot with title "Histogram of x"
# Plot with title "Histogram of x"

# %%
dona <- c(10000,20000,50000,40000,40000,40000,40000,30000,10000,10000)
hist(dona)
boxplot(dona)
# Out:
# Plot with title "Histogram of dona"
# plot without title

# %%
x <- c(1,2,2,1,3,3,1,5)
hist(x)
barplot(x)

d1<- c(1,2,2,1,3)
d2 <- c("a",'b','c','d','e')

barplot(d1,names.arg = d2)
# Out:
# Plot with title "Histogram of x"
# plot without title
# plot without title

# %%
menu <- c("짜장면","짬뽕","우동","볶음밥","탕수육","짜장면","짜장면","우동","볶음밥","짜장면","탕수육",
         "우동","짜장면","볶음밥","탕수육","짜장면","짬뽕","짜장면","짬뽕")

menu_freq <- table(menu)
barplot(menu_freq)
# Out:
# plot without title

# %%
x <- c(1,2,2,1,3,3,1,5)
pie(x)

pie(table(x))
# Out:
# plot without title
# plot without title

# %%
par(mfrow = c(2,2))
sales <- c(5,19,12,9,7,29,15)
pie(sales)
x2 <- c("김무현","이희연","장흥식","노천수","박만연","최성락","김홍식")
pie(sales)
#정확한 수치를 명시하기 위해 label을 사용
pie(sales,label = sales)
# 수치와 판매사원에 대한 정보를 동시에 제공하기 위해 label과 paste를 활용
pie(sales,label = paste(x2,sales))
# Out:
# plot without title

# %%
sales <- c("김영희","오영란","박춘길","조성해","윤득호","오미영","오영란","오미영",
          "김영희","윤득호","조성해","김영희","박춘길","박춘길","오미영","윤득호")

sales_freq <- table(sales)

pie(sales_freq)
# Out:
# plot without title

# %%
# barplot(),pie() 로 그려지는 기본 그래프는 쉽고 유용하지만 보충정보가 필요

# %%
x <- c(1,2,2,1,3,3,1,4) #자료업리겨
x2 <- table(x)
bp <- boxplot(x2)

percent <- (x2/sum(x2)*100)

text(x = bp, y = x2,labels = percent)
text(x = bp, y = x2,labels = percent,pos = 1)
# Out:
# Error in Axis.table(x = structure(c(1, 1.5, 2, 2.5, 3), .Dim = c(5L, 1L: only for 1-D table
# Traceback:
#
# 1. boxplot(x2)
# 2. boxplot.default(x2)
# 3. do.call("bxp", c(list(z, notch = notch, width = width, varwidth = varwidth,
#  .     log = log, border = border, pars = pars, outline = outline,
#  .     horizontal = horizontal, add = add, at = at), args[namedargs]))
# 4. bxp(list(stats = structure(c(1, 1.5, 2, 2.5, 3), .Dim = c(5L,
#  . 1L), class = c(`1` = "table")), n = 4, conf = structure(c(1.21,
#  . 2.79), .Dim = 2:1), out = numeric(0), group = numeric(0), names = "1"),
#  .     notch = FALSE, width = NULL, varwidth = FALSE, log = "",
#  .     border = "black", pars = list(boxwex = 0.8, staplewex = 0.5,
#  .         outwex = 0.5), outline = TRUE, horizontal = FALSE, add = FALSE,
#  .     at = NULL)
# 5. do.call("Axis", c(list(x = z$stats, side = 2 - horizontal), ax.pars))
# 6. Axis(x = structure(c(1, 1.5, 2, 2.5, 3), .Dim = c(5L, 1L), class = c(`1` = "table")),
#  .     side = 2)
# 7. Axis.table(x = structure(c(1, 1.5, 2, 2.5, 3), .Dim = c(5L, 1L
#  . ), class = c(`1` = "table")), side = 2)
# 8. stop("only for 1-D table")
# plot without title

# %%
x <- c(1,2,2,1,3,3,1,5)
x2 <- table(x)

# %%
install.packages("RColorBrewer")
# Out:
# Warning message:
# "unable to access index for repository http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5:
#   URL 'http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5/PACKAGES'를 열 수 없습니다"
# package 'RColorBrewer' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpI3klrc\downloaded_packages

# %%
library(RColorBrewer)
pal <- brewer.pal(12,'Set3')
bp <- barplot(x2,col = pal)
percent <- round(x2/sum(x2)*100, digit = 1)
text(x = bp, y = x2 - 0.1, labels = percent)
# Out:
# plot without title

# %%
color <- c('black',"white","pink")
ea <- c(5,2,3)
barplot(ea, names.org = color)
pie(ea,labels = color)
# Out:
# Warning message in plot.window(xlim, ylim, log = log, ...):
# ""names.org"는 그래픽 매개변수가 아닙니다"Warning message in title(main = main, sub = sub, xlab = xlab, ylab = ylab, ...):
# ""names.org"는 그래픽 매개변수가 아닙니다"Warning message in axis(if (horiz) 1 else 2, cex.axis = cex.axis, ...):
# ""names.org"는 그래픽 매개변수가 아닙니다"
# plot without title
# plot without title

# %%
# 나무지도를 만드는 라이브러리 
install.packages("treemap")
library(treemap)
# Out:
# also installing the dependency 'gridBase'
#
# Warning message:
# "unable to access index for repository http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5:
#   URL 'http://www.stats.ox.ac.uk/pub/RWin/bin/windows/contrib/3.5/PACKAGES'를 열 수 없습니다"
# package 'gridBase' successfully unpacked and MD5 sums checked
# package 'treemap' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Administrator\AppData\Local\Temp\RtmpI3klrc\downloaded_packages

# %%
data(GNI2014)

# %%
head(GNI2014)
# Out:
#   iso3 country          continent     population GNI
# 3 BMU  Bermuda          North America   67837    106140
# 4 NOR  Norway           Europe        4676305    103630
# 5 QAT  Qatar            Asia           833285     92200
# 6 CHE  Switzerland      Europe        7604467     88120
# 7 MAC  Macao SAR, China Asia           559846     76270
# 8 LUX  Luxembourg       Europe         491775     75990

# %%
treemap(GNI2014,
    index = c("continent","iso3"),
    vSize = 'population',
    vColor = 'GNI',
    type = 'value' ,
    bg.labels = 'yellow')


inedx = c("continet",iso3)

type = 'value'
# Out:
# Error in eval(expr, envir, enclos): 객체 'iso3'를 찾을 수 없습니다
# Traceback:
# plot without title

# %%
# 대륙별 인구, 소득 구하기
GNI2014$GNI.total <- GNI2014$population*GNI2014$GNI

# 국가별 국민 총소득을 대륙별로 합계내서 GNI2014로 저장
GNI2014.a <- aggregate(GNI2014[,4:6],
                      by=list(GNI2014$continent),sum)

#대륙별 합계를 대륙 인구수로 냐눔
GNI2014.a$GNI.percap <- GNI2014.a$GNI.total/GNI2014.a$population

GNI2014.a
# Out:
#   Group.1                 population GNI     GNI.total    GNI.percap
# 1 Africa                   962382035  104830 1.961970e+12  2038.660
# 2 Asia                    4033277009  728150 2.516533e+13  6239.425
# 3 Europe                   728669949 1211610 2.099551e+13 28813.465
# 4 North America            528748158  404540 2.054819e+13 38861.968
# 5 Oceania                   33949312  153400 1.567946e+12 46184.899
# 6 Seven seas (open ocean)    1768074   30140 1.614137e+10  9129.355
# 7 South America            394352338  110350 4.189948e+12 10624.885

# %%
treemap(GNI2014.a,
    index = c("Group.1"),
    vSize = 'population',
    vColor = 'GNI.percap',
    type = 'value',
    bg.labels = 'yellow')
# Out:
# plot without title

# %%
# 버블차트

# %%
library(MASS)

# %%
head(UScrime)
# Out:
#   M   So Ed  Po1 Po2 LF  M.F  Pop NW  U1  U2 GDP Ineq Prob     Time    y
# 1 151 1   91  58  56 510  950  33 301 108 41 394 261  0.084602 26.2011  791
# 2 143 0  113 103  95 583 1012  13 102  96 36 557 194  0.029599 25.2999 1635
# 3 142 1   89  45  44 533  969  18 219  94 33 318 250  0.083401 24.3006  578
# 4 136 0  121 149 141 577  994 157  80 102 39 673 167  0.015801 29.9012 1969
# 5 141 0  121 109 101 591  985  18  30  91 20 578 174  0.041399 21.2998 1234
# 6 121 0  110 118 115 547  964  25  44  84 29 689 126  0.034201 20.9995  682

# %%
radius <- sqrt(UScrime$Pop)

# %%
symbols(UScrime$U2, UScrime$y, #원의 x,y좌표값
       circles = radius, # 원의 반지름
       inches = 0.3, # 원의 크기 조절값
       fg = 'white', #원의 테두리 값
       bg = 'lightgray', #원의 바탕색 
       lwd = 1.5, #원의 테두리선 두께
       xlab = 'unemployment 35-39 males',
       ylab = 'crime rate',
       main = 'UScrime Data')

text(UScrime$U2, UScrime$y,
    1:nrow(UScrime),
    cex = 0.8,
    col = 'brown')
# Out:
# Plot with title "UScrime Data"

# %%
df <- read.csv("Seoul_temp_2017.csv")

# %%
head(df)
summary(df)
# Out:
#   date       month avg_temp
# 1 2017-01-01 1     2.7
# 2 2017-01-02 1     5.0
# 3 2017-01-03 1     2.0
# 4 2017-01-04 1     3.9
# 5 2017-01-05 1     3.8
# 6 2017-01-06 1     5.4
#          date         month           avg_temp
#  2017-01-01:  1   Min.   : 1.000   Min.   :-9.40
#  2017-01-02:  1   1st Qu.: 4.000   1st Qu.: 3.00
#  2017-01-03:  1   Median : 7.000   Median :15.10
#  2017-01-04:  1   Mean   : 6.526   Mean   :13.07
#  2017-01-05:  1   3rd Qu.:10.000   3rd Qu.:22.60
#  2017-01-06:  1   Max.   :12.000   Max.   :31.40
#  (Other)   :359

# %%
boxplot(df$avg_temp,
       col = 'yellow',
       ylim = c(-20,40),
       xlab = '서울 1년 기온',
       ylab = '기온')
# Out:
# plot without title

# %%
# 월별 평균 기온 계산
month.avg <- aggregate(df$avg_temp,by = list(df$month),median) [2]

# 평균 기온 순위 계산(내림차순)

odr <- rank(-month.avg)

#월별 기온 분포 
boxplot(avg_temp~ month, data = df,
       col = heat.colors(12)[odr],
       ylim = c(-20,40),
       ylab = "기온",
       xlab = '월',
       main = '서울 월별기온분포(2017)')
# Out:
# Plot with title "서울 월별기온분포(2017)"

# %%
#matrix 형태로 데이터가 존재하는 경우 
hospital <- read.csv("hospital.csv")
head(hospital)
table(hospital)
mosaicplot(~freq + stay, data = hospital, color = TRUE, 
          main = '병원내원빈도 vs 치료기간')
# Out:
#   freq    stay
# 1 Regular 2-9
# 2 Regular 2-9
# 3 Regular 2-9
# 4 Regular 2-9
# 5 Regular 2-9
# 6 Regular 2-9
#                    stay
# freq                10-19 2-9 20+
#   Less than monthly    11   6  10
#   Never                18   9  16
#   Regular              16  43   3
# Plot with title "병원내원빈도 vs 치료기간"

# %%
mosaicplot(~freq + stay, data = hospital, color = c("green","blue","red"),
          main = '병원내원빈도vs치료기간')
# Out:
# Plot with title "병원내원빈도vs치료기간"

# %%
# 두가지 방법으로 모자이크 플롯 그리기 
# 1
mosaicplot(~ freq + stay, data = hospital, color = T)

# 2 
tbl <- table(hospital)
mosaicplot(tbl,data = hospital, color = T)
# Out:
# Warning message:
# "In mosaicplot.default(tbl, data = hospital, color = T) :
#  extra argument 'data' will be disregarded"
# Plot with title "hospital"
# Plot with title "tbl"

# %%
#3차원 교차표 형태로 데이터가 존재하는 경우 
mosaicplot(Titanic,main = 'Survival on the Titanic',
           color= c("red",'green'), off = 3)
# Out:
# Plot with title "Survival on the Titanic"

# %%
# plot을 만드는 여러가지 방법 
x <- c(1,2,3,4,5,6)
y <- c(2,5,7,12,15,20)
plot(x,y,xlab = 'time',ylab = 'effect')
library(ggplot2)
# 심미성이 높음 
qplot(x,y,xlab = 'time',ylab = 'effect')
# ggplot의 경우 df형태이어야 한다. 
df <- data.frame(time = x,effect = y)
ggplot(df,aes(x = time,y = effect)) + geom_point()
# Out:
# plot without title
# plot without title
# plot without title

# %%
# ggplot의 두가지 스타일 

#스타일 1
ggplot(df,aes(x = time, y = effect)) + geom_line()

# 스타일2
ggplot() + geom_line((df,aesx = time, y = effect)) + .. 

# 스타일1은 단일 그래프를 그릴때, 스타일 2는 여러 그래프를 하나로 겹쳐 그릴때 편리

# %%
ggplot(data = iris, aes(x = Petal.Length,y = Petal.Width)) + geom_point()

ggplot() + geom_point(data = iris, aes(x = Petal.Length, y = Petal.Width),
                     color = 'red')
# Out:
# plot without title
# plot without title

# %%
# geom_point() 옵션 적용하기 

gp <- ggplot(data = iris, aes(x = Petal.Length, 
                              y = Petal.Width))  + geom_point(aes(color = Species, shape = Species),alpha = 0.5, size = 2)
gp
# Out:
# plot without title

# %%
time <- c(1,2,3,4,5,6)
effect <- c(2,5,7,12,15,20)
effect2 <- c(1,3,5,8,11,18)
plot(time, effect , type = 'l')
lines(time,effect2,col = 'red')
# Out:
# plot without title

# %%
df <- data.frame(time, effect, effect2)
ggplot() + geom_line(
    data = df,aes(x = time,y = effect)) + geom_line(
    data = df,aes(x = time, y = effect2),col = 'red') + geom_point(
    size = 2.7,color = 'white')
# Out:
# plot without title

# %%
df <- read.csv('heightweight.csv',header = T)

# %%
head(df)
# Out:
#   sex ageYear ageMonth heightIn weightLb
# 1 f   11.92   143      56.3      85.0
# 2 f   12.92   155      62.3     105.0
# 3 f   12.75   153      63.3     108.0
# 4 f   13.42   161      59.0      92.0
# 5 f   15.92   191      62.5     112.5
# 6 f   14.25   171      62.5     112.0

# %%
ggplot() + geom_line(data = df, aes(x = df$ageMonth,y = df$height, colour = df$sex))
# Out:
# plot without title

# %%
ggplot() + geom_point(data = df, aes(x = df$ageMonth,y = df$height, colour = df$sex))
# Out:
# plot without title

# %%
df = data.frame (table(mtcars$carb))
df
ggplot(df,aes(x = Var1, y = Freq) ) + geom_bar(stat = 'identity', width = 0.7, fill = 'steelblue')
# Out:
#   Var1 Freq
# 1 1     7
# 2 2    10
# 3 3     3
# 4 4    10
# 5 6     1
# 6 8     1
# plot without title

# %%
# 박스플롯 그리기 

ggplot() + geom_boxplot(data = iris,
                       aes(x = Species, y = Petal.Length,fill = Species))
# Out:
# plot without title

# %%
# 누적 영역 그래프 그리기 
data <- read.csv("uspopage.csv")
head(data)
ggplot(data, aes(x = Year, y = Thousands)) + geom_area()
ggplot(data, aes(x = Year, y = Thousands,fill = AgeGroup)) + geom_area()
# Out:
#   Year AgeGroup Thousands
# 1 1900 00~04     9181
# 2 1900 05~14    16966
# 3 1900 15~24    14951
# 4 1900 25~34    12161
# 5 1900 35~44     9273
# 6 1900 45~54     6437
# plot without title
# plot without title

# %%
df <- read.csv('electricity.csv')
head(df)
ggplot(df, aes(x = Year,y = Usage, fill = Part)) + geom_area()

ggplot(df, aes(x = Year, y = Usage, fill = Part)) + geom_area() + scale_fill_brewer(breaks = rev(levels(data$Part)))
# Out:
#   Year Part       Usage
# 1 2001 산업       85158
# 2 2001 수송       31909
# 3 2001 가정및상업 32893
# 4 2001 공공및기타  2989
# 5 2002 산업       89197
# 6 2002 수송       33763
# plot without title
# plot without title
